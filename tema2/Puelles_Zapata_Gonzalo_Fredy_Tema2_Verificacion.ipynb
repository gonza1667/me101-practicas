# %%
import pandas as pd
import numpy as np
# Completa: imprime un mensaje de confirmacion
# y las versiones de pandas y numpy
print("Entorno me101 verificado correctamente - Gonzalo Puelles Zapata")
print("pandas:", pd.__version__, "| numpy:", np.__version__)
# Out:
# Entorno me101 verificado correctamente - Gonzalo Puelles Zapata
# pandas: 3.0.5 | numpy: 2.4.6
